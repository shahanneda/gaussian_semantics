# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

img = plt.imread('/home/shahanneda/gs-data/panoptic-nerf-data/scannet/scene0423_02/rs_instance/350.png')
# 0.00392157
# img = plt.imread('/home/shahanneda/gs-data/panoptic-nerf-data/scannet/scene0423_02/m2f_instance/2.png')
# img = plt.imread('/home/shahanneda/gs-data/panoptic-nerf-data/scannet/scene0423_02/rs_instance/0.png')
# img = mpimg.imread('/home/shahanneda/gs-data/panoptic-nerf-data/scannet/scene0423_02/instance/0.png')
print(img.shape)
print(np.unique(img))
plt.imshow(img)
plt.show()
# Out:
# (968, 1296)
# [0.         0.00784314 0.01176471 0.01568628]
